# %%
import yt_dlp
import os
from moviepy.video.io.VideoFileClip import VideoFileClip
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
import json
import boto3
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from concurrent.futures import ThreadPoolExecutor

import cv2
import numpy as np
import sys
import random

# %% [markdown]
# # Setup

# %%
log_file = open("output_log.txt", "w")
sys.stdout = log_file

# %%
secret_name = "youtube"
region_name = "us-east-1"

# Create a Secrets Manager client
session = boto3.session.Session()
secretsmanager = session.client(service_name='secretsmanager', region_name=region_name)

get_secret_value_response = secretsmanager.get_secret_value(SecretId=secret_name)

secret = get_secret_value_response['SecretString']
api_key = json.loads(secret)["API_KEY"]

# %%
total_duration = 0

# %%
s3_client = boto3.client('s3')
bucket = 'slip-ml'

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

# %%
torch_dtype = torch.float32

# %%
model_id = "openai/whisper-large-v3-turbo"
model = AutoModelForSpeechSeq2Seq.from_pretrained(model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True)
model.to(device)
processor = AutoProcessor.from_pretrained(model_id)

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
)
# Out:
# Device set to use mps

# %% [markdown]
# # Gather and Save Raw Data

# %%
def get_playlist_videos(playlist_url):
    """
    Extract all video URLs from a YouTube playlist using the YouTube Data API.
    
    Args:
        playlist_url (str): The YouTube playlist URL (e.g., https://www.youtube.com/playlist?list=PL86SiVwkw_odmp-RVzD8yef3wU7Z2uD5a)
        api_key (str): Your YouTube Data API key
    
    Returns:
        list: List of video URLs
    """
    # Extract playlist ID from URL
    playlist_id = playlist_url.split("list=")[-1].split("&")[0]
    
    # Initialize YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)
    
    video_urls = []
    next_page_token = None
    
    try:
        while True:
            # Request playlist items
            request = youtube.playlistItems().list(
                part="contentDetails",
                playlistId=playlist_id,
                maxResults=50,  # Max allowed per request
                pageToken=next_page_token
            )
            response = request.execute()
            
            # Extract video IDs and create URLs
            for item in response['items']:
                video_id = item['contentDetails']['videoId']
                video_url = f"https://www.youtube.com/watch?v={video_id}"
                video_urls.append(video_url)
            
            # Check for next page
            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break
    
    except HttpError as e:
        print(f"An error occurred: {e}")
        return []
    
    return video_urls

# %%
def upload_to_s3(local_file, s3_folder):
    s3_file = f"{s3_folder}/{local_file}"
    
    # Upload the file
    s3_client.upload_file(local_file, bucket, s3_file)
    print(f"Upload Successful: {local_file} -> {s3_file}")

# %%
def download_youtube_video_yt_dlp(url):
    # extract video ID from the URL
    video_id = url.split("v=")[-1]
    if "&" in video_id:
        video_id = video_id.split("&")[0]

    ydl_opts = {
        "outtmpl": f"{video_id}.%(ext)s",  # Output path and filename
        "format": "best",  # Select the best single file (video + audio)
        "merge_output_format": None,  # Avoid merging, stick to single stream
    }
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
        print("Download completed successfully!")
        upload_to_s3(video_id + '.mp4', 'data/raw')
        return video_id
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def get_video_chunk_names(path):
    # extract video ID from the filename
    video_id = path.split('__')[0]
    chunk_name = path.split('__')[2].split('.')[0]
    return video_id, chunk_name

# %%
def split_audio_video(video_file):
    try:
        # extract video ID from the filename
        video_id, chunk_name = get_video_chunk_names(video_file)
        print(f"Video ID: {video_id}, Chunk Name: {chunk_name}")

        # import video
        video_chunk = VideoFileClip(video_file)

        # Split audio and video
        audio_path = os.path.join(f"{video_id}__audio__{chunk_name}.mp3")
        video_path = os.path.join(f"{video_id}__video__{chunk_name}.mp4")
        print(f"Audio path: {audio_path}, Video path: {video_path}")


        # Write audio to file
        video_chunk.audio.write_audiofile(audio_path)

        # Write video to file
        video_only = video_chunk.without_audio()
        video_only.write_videofile(video_path, codec="libx264", audio_codec="aac")
        #upload_to_s3(video_path, "data/video")

        # Close the video clip
        video_chunk.close()
        video_only.close()

        # delete chunk video file
        os.remove(video_file)

        print("Audio and video split successfully!")
        return audio_path, video_path
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def clip_video_into_chunks(video_id):
    global total_duration
    input_file = video_id + '.mp4'
    try:
        video = VideoFileClip(input_file)
        duration = int(video.duration) - 30  # Get the duration of the video in seconds
        total_duration += duration

        chunk_length = 3  # Length of each chunk in seconds
        chunks = []

        for start in range(0, duration, chunk_length):
            end = min(start + chunk_length, duration)
            chunk = video.subclipped(start, end)
            chunk_filename = f"{video_id}__chunk__{start // chunk_length}.mp4"
            chunk.write_videofile(chunk_filename, codec="libx264")
            chunks.append(chunk_filename)

        video.close()

        # detele original video file
        os.remove(input_file)

        return chunks
    except Exception as e:
        print(f"An error occurred while splitting the video: {e}")
        return []

# %%
def audio_to_text(audio_file):
    try:
        # Use Whisper with English speech detection
        result = pipe(
            f"{os.getcwd()}/{audio_file}",
            generate_kwargs={"language": "en", "task": "transcribe"}
        )
        text = result["text"].strip()
        video_id, chunk_name = get_video_chunk_names(audio_file)
        
        # Validate text
        MAX_TEXT_LENGTH = 100  # ~10-20 words for 3 seconds
        MIN_TEXT_LENGTH = 15   # Ensure meaningful transcription
        if not text or len(text) < MIN_TEXT_LENGTH:
            print(f"Insufficient text length {len(text)} for {audio_file}: '{text}'")
            os.remove(audio_file)
            return None, video_id, chunk_name
        if len(text) > MAX_TEXT_LENGTH:
            print(f"Excessive text length {len(text)} for {audio_file}: '{text[:50]}...'")
            os.remove(audio_file)
            return None, video_id, chunk_name
        
        print(f"Transcription for {audio_file}: '{text}' (length: {len(text)})")
        
        data = {
            "video_id": video_id,
            "chunk_name": chunk_name,
            "text": text
        }
        json_file = f"{video_id}__text__{chunk_name}.json"
        with open(json_file, "w") as f:
            json.dump(data, f, indent=4)
        print(f"Text saved to {json_file}")
        #upload_to_s3(json_file, "data/text")
        os.remove(audio_file)
        os.remove(json_file)
        return text, video_id, chunk_name
    except Exception as e:
        print(f"Error transcribing {audio_file}: {e}")
        return None, video_id, chunk_name

# %%
def weighted_train_test_split():
    """
    Randomly returns 'train' or 'test' with a 90/10 weighted probability.

    Returns:
        str: 'train' (90% probability) or 'test' (10% probability).
    """
    return random.choices(['train', 'test'], weights=[90, 10], k=1)[0]

# %% [markdown]
# # Preprocessing Option 1 & 2

# %%
# 1 is larger image files
# 2 is smaller image files
preprocessing_option = 2

# %%
def save_numpy_file(numpy_path, frames, train_test_split):
    print('saving video frames to numpy file')
    np.savez_compressed(numpy_path, frames=frames)
    full_path = numpy_path+'.npz'
    upload_to_s3(full_path, "data/preprocessing-{}/{}/videos".format(preprocessing_option, train_test_split))
    os.remove(full_path)

# %%
def preprocess_video(video_path, img_w, img_h, frames_n):
    video_id, chunk_name = get_video_chunk_names(video_path)
    print(f"Preprocessing video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    frames = []
    frame_count = 0
    while frame_count < frames_n:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, (img_w, img_h))
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = frame / 255.0
        if np.isnan(frame).any() or np.isinf(frame).any():
            print(f"Invalid frame {frame_count} in {video_path}, skipping")
            cap.release()
            os.remove(video_path)
            return None
        frames.append(frame)
        frame_count += 1
    cap.release()
    if len(frames) == 0:
        print(f"No valid frames in {video_path}, skipping")
        os.remove(video_path)
        return None
    while len(frames) < frames_n:
        frames.append(np.zeros((img_h, img_w, 3)))
    frames = np.array(frames)
    if np.isnan(frames).any() or np.isinf(frames).any():
        print(f"Invalid frames array in {video_path}, skipping")
        os.remove(video_path)
        return None
    train_test_split = weighted_train_test_split()
    numpy_path = f"{video_id}__numpy__{chunk_name}"
    with ThreadPoolExecutor() as executor:
        executor.submit(save_numpy_file, numpy_path, frames, train_test_split)
    os.remove(video_path)
    return train_test_split

# %%
# Example character-to-index mapping
char_to_idx = {char: idx for idx, char in enumerate(" abcdefghijklmnopqrstuvwxyz'.?!")} 

def text_to_labels(text, video_id, chunk_name, train_test_split):
    if text is None:
        print(f"Skipping text_to_labels for {video_id}__{chunk_name} due to invalid text")
        return
    
    labels = [char_to_idx[char] for char in text.lower() if char in char_to_idx]
    
    # Validate labels
    MAX_LABEL_LENGTH = 80   # Reasonable for 3-second chunk
    MIN_LABEL_LENGTH = 10   # Ensure meaningful labels
    if not labels or len(labels) < MIN_LABEL_LENGTH:
        print(f"Insufficient label length {len(labels)} for {video_id}__{chunk_name}: '{text}'")
        return
    if len(labels) > MAX_LABEL_LENGTH:
        print(f"Excessive label length {len(labels)} for {video_id}__{chunk_name}: '{text[:50]}...'")
        return
    
    json_file = f"{video_id}__text__{chunk_name}.json"
    with open(json_file, "w") as f:
        json.dump({"text": text, "labels": labels}, f)
    print(f"Labels saved to {json_file}, Length: {len(labels)}")
    upload_to_s3(json_file, f"data/preprocessing-{preprocessing_option}/{train_test_split}/labels")
    os.remove(json_file)

# %% [markdown]
# # Do the Work

# %%
# get list of YT video urls
playlist_urls = ["https://www.youtube.com/playlist?list=PL86SiVwkw_odmp-RVzD8yef3wU7Z2uD5a",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_ocn2nwGFoFWkBN8pFwgUshe",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_oe-sPwrWqm0k7t8bOK8dFpB",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_ofCWfjyBWs4PES8w-5AwPbx",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_oeR6BsaVjOwHunDOyAmDYxc",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_ocJPhcA3xiqszDcyIiGIt5y",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_oeLwHETCekBrdfP7M93LOpU",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_odq_rn2jUfdDAYgQfvijNtp",
                 "https://www.youtube.com/playlist?list=PL86SiVwkw_ofqbtdqZzFgzd--kxXhdRB4"]

all_video_urls = []
for playlist_url in playlist_urls:
    video_urls = get_playlist_videos(playlist_url)
    all_video_urls.extend(video_urls)

# remove duplicate video urls
all_video_urls = list(set(all_video_urls))
print(f"Total videos after removing duplicates: {len(all_video_urls)}")

# randomly shuffle the video urls
random.shuffle(all_video_urls)

# %%
last_video_num = 0
# for i, video_url in enumerate(all_video_urls):
#     if '74M0hPAeFHs' in video_url:
#         print(f"Skipping video {i+1}/{len(all_video_urls)}: {video_url}")
#         last_video_num = i
#         continue

# %%
frames_n = 90 #300
img_w = 100 #1920//5
img_h = 50 #1080//5

# %%
for i, url in enumerate(all_video_urls[103:], start=last_video_num+1):
    print(f"*******************************************************Processing video {i} of {len(all_video_urls)}********************************************************")
    video_name = download_youtube_video_yt_dlp(url)
    if not video_name:
        print(f"Failed to download video {i} of {len(all_video_urls)}")
        continue
    os.remove(video_name + '.mp4')
# Out:
# ERROR: [youtube] 6f_Z5OBzY1k: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] FNLQdquN0-I: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] YtHSBazG1mA: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] -G1mAiRLK3I: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] 8md6Rpxoz2Y: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] J3Dc6UV1ML4: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] u_G4el-62Ik: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [download] Got error: 95935 bytes read, 9871713 more expected
# ERROR: [youtube] 0dGLAOaTgyw: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] O7DqmMyLAps: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] KZnb8InfpHI: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] syjdYGc2A20: Some ios client https formats have been skipped as they are missing a url. The current session may have the SSAP (server-side ads) experiment which interferes with yt-dlp. Please see  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details.
# ERROR: [youtube] YXFkCH90yYQ: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] fiVno2_W0U8: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] PiMWCFay_sE: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] c-THItUk9aU: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] KU11frG97iw: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] PfASgUNxAd4: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] GSf5nUSW5uE: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] AO_t7GtXO6w: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] 7gjTqphb6Gg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] HoV0sUaISgo: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] 2lVRcI0zsvw: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] -tCW78kqpwg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] jrhvsb9Yrz8: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] bdkhPkCUPnU: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] RS1Uh6ohTLM: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] Bzk_5Jzvxdk: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] wr-TychE8Vk: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] h0je0iSC1Hg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] KR9kOco2dpQ: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 25D3SlGLFKg: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] kndkb938iRo: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] NXmrhupyod0: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] e2f-cR26wbw: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] YHESC4c6c2c: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 7VkW_shf8yg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] 4w2u4TaSKOc: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] FWUeJ_AzZFQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] VONBpGWaxL8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] JZAa-4s0Ffg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] ymLcrCeaWTc: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] M94-kf_lXUA: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] zkpKPSX8ziY: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] _d-5UI_murs: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] BoJJZzltguQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] y6daxZDW37Y: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] ri44Zx810p0: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 3Ds7T7rKKZY: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] aex6V8aGvxY: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] ZD7JwlAtzNc: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] QczF5CcePvo: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] USS_p-4vo2w: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] gmqPgkDn2Qg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] qbRoK8WhJQQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] I8HPyC3uxo8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] M4YOZHoDSyg: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] NicnafggIVA: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] f2qMixdZN80: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] 3XsYBadvZXg: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] IaZ_L5pnF6k: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] dgQWY0CN1J8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] 3Pj2JayTVLM: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] D28DChSbG74: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] ncDQvy5GoK8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] sN16d6mhe-A: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] -4GsCEopbd4: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] taBWQmEnbf4: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 8bTCurSCdtg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] cltsjpK24Zo: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] KlfCBX2CwMM: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] yX0WnX27tJw: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] n11B_5A3lDo: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] RfZOtkoQleM: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] LATrHU5LEF4: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] c6GEJoLDcAs: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] iJiQsEZXz_8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] mcacOjVLEF0: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] mKpQB3bEPbI: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [download] Got error: 99515 bytes read, 7593643 more expected
# ERROR: [youtube] 3cExaGj6nj8: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 3EfuzJShes0: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] hp7R8rnLvw0: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] NYEGCSHHKqo: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] d4KlS5t2C4Y: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] VA6nnlleAb4: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] FQaal5ozf4w: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] Lr5f_HoFE-8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] aTyJ3QruoaM: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ERROR: [youtube] Sb5v6XvZKXY: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 58Fwf8tIUw8: Video unavailable. The uploader has not made this video available in your country
# ERROR: [youtube] 5rvk07eB9wk: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies

# %%
for i, url in enumerate(all_video_urls[:150], start=last_video_num+1):
    print(f"*******************************************************Processing video {i} of {len(all_video_urls)}********************************************************")
    try:
        video_name = download_youtube_video_yt_dlp(url)
        if not video_name:
            print(f"Failed to download video {i} of {len(all_video_urls)}")
            continue
        video_chunks = clip_video_into_chunks(video_name)
        for chunk in video_chunks:
            #### General Preprocessing Steps ####
            audio_path, video_path = split_audio_video(chunk)
            text, video_id, chunk_name = audio_to_text(audio_path)
            ##### Preprocessing Steps #####
            if text is None:
                        print(f"Skipping chunk {chunk_name} due to transcription failure")
                        os.remove(video_path)
                        continue
            train_test_split = preprocess_video(video_path, img_w, img_h, frames_n)
            if train_test_split is None:
                print(f"Skipping chunk {chunk_name} due to invalid frames")
                continue
            text_to_labels(text, video_id, chunk_name, train_test_split)

    except Exception as e:
        print(f"An error occurred: {e}")
        continue
# Out:
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]          /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__0.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__1.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  82%|████████▏ | 59/72 [00:00<00:00, 526.42it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__2.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  99%|█████████▊| 71/72 [00:00<00:00, 640.38it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__3.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  93%|█████████▎| 67/72 [00:00<00:00, 518.10it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__4.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__5.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__6.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__7.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__8.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__9.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__10.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__11.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__12.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  83%|████████▎ | 60/72 [00:00<00:00, 598.28it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__13.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index: 100%|██████████| 72/72 [00:00<00:00, 613.16it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__14.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__15.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__16.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__17.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__18.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__19.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  88%|████████▊ | 63/72 [00:00<00:00, 561.45it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__20.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  86%|████████▌ | 62/72 [00:00<00:00, 615.31it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__21.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__22.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  99%|█████████▊| 71/72 [00:00<00:00, 699.54it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__23.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__24.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  93%|█████████▎| 67/72 [00:00<00:00, 657.67it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__25.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__26.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__27.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__28.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__29.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__30.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  85%|████████▍ | 61/72 [00:00<00:00, 542.99it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__31.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   3%|▎         | 2/72 [00:00<00:04, 16.47it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__32.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__33.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__34.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__35.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__36.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__37.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  85%|████████▍ | 61/72 [00:00<00:00, 552.73it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__38.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  92%|█████████▏| 66/72 [00:00<00:00, 598.55it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__39.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__40.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__41.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__42.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/24 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file qeY1mkXqKgk__chunk__43.mp4, 691200 bytes wanted but 0 bytes read at frame index 23 (out of a total 24 frames), at time 0.96/1.02 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]          /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__0.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index: 100%|██████████| 72/72 [00:00<00:00, 716.75it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__1.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__2.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__3.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  54%|█████▍    | 39/72 [00:00<00:00, 387.96it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__4.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__5.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__6.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  93%|█████████▎| 67/72 [00:00<00:00, 655.40it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__7.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__8.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__9.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__10.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__11.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  82%|████████▏ | 59/72 [00:00<00:00, 573.86it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__12.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__13.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__14.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  96%|█████████▌| 69/72 [00:00<00:00, 607.85it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__15.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__16.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__17.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  83%|████████▎ | 60/72 [00:00<00:00, 576.86it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__18.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__19.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__20.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  79%|███████▉  | 57/72 [00:00<00:00, 278.13it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__21.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__22.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__23.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__24.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__25.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__26.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file p12OcbmjVgU__chunk__27.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   6%|▌         | 4/72 [00:00<00:02, 25.57it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__38.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  28%|██▊       | 20/72 [00:00<00:00, 197.90it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__39.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  67%|██████▋   | 48/72 [00:00<00:00, 475.94it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__40.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  85%|████████▍ | 61/72 [00:00<00:00, 320.33it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__41.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  86%|████████▌ | 62/72 [00:00<00:00, 292.86it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__42.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  88%|████████▊ | 63/72 [00:00<00:00, 244.12it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__43.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:   0%|          | 0/72 [00:00<?, ?it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__44.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  53%|█████▎    | 38/72 [00:00<00:00, 234.48it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__45.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  93%|█████████▎| 67/72 [00:00<00:00, 664.36it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__46.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  62%|██████▎   | 45/72 [00:00<00:00, 375.44it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__47.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  72%|███████▏  | 52/72 [00:00<00:00, 519.50it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__48.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  99%|█████████▊| 71/72 [00:00<00:00, 323.30it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__49.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  53%|█████▎    | 38/72 [00:00<00:00, 119.49it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__50.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  92%|█████████▏| 66/72 [00:00<00:00, 169.69it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__51.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  64%|██████▍   | 46/72 [00:00<00:00, 456.91it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__52.mp4, 691200 bytes wanted but 0 bytes read at frame index 71 (out of a total 72 frames), at time 2.96/3.01 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# frame_index:  75%|███████▌  | 18/24 [00:00<00:00, 170.69it/s, now=None]/Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:178: UserWarning: In file MwlpVojvQms__chunk__53.mp4, 691200 bytes wanted but 0 bytes read at frame index 23 (out of a total 24 frames), at time 0.96/1.02 sec. Using the last valid frame instead.
#   warnings.warn(
# /Users/emmettstorts/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 4
#       2 print(f"*******************************************************Processing video {i} of {len(all_video_urls)}********************************************************")
#       3 try:
# ----> 4     video_name = download_youtube_video_yt_dlp(url)
#       5     if not video_name:
#       6         print(f"Failed to download video {i} of {len(all_video_urls)}")
#
# Cell In[32], line 16, in download_youtube_video_yt_dlp(url)
#      14         ydl.download([url])
#      15     print("Download completed successfully!")
# ---> 16     upload_to_s3(video_id + '.mp4', 'data/raw')
#      17     return video_id
#      18 except Exception as e:
#
# Cell In[12], line 5, in upload_to_s3(local_file, s3_folder)
#       2 s3_file = f"{s3_folder}/{local_file}"
#       4 # Upload the file
# ----> 5 s3_client.upload_file(local_file, bucket, s3_file)
#       6 print(f"Upload Successful: {local_file} -> {s3_file}")
#
# File ~/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/boto3/s3/inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)    172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File ~/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/boto3/s3/transfer.py:372, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     368 future = self._manager.upload(
#     369     filename, bucket, key, extra_args, subscribers
#     370 )
#     371 try:
# --> 372     future.result()
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#     377 except ClientError as e:
#
# File ~/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/s3transfer/futures.py:114, in TransferFuture.result(self)
#     112 except KeyboardInterrupt as e:
#     113     self.cancel()
# --> 114     raise e
#
# File ~/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/s3transfer/futures.py:111, in TransferFuture.result(self)
#     106 def result(self):
#     107     try:
#     108         # Usually the result() method blocks until the transfer is done,
#     109         # however if a KeyboardInterrupt is raised we want want to exit
#     110         # out of this and propagate the exception.
# --> 111         return self._coordinator.result()
#     112     except KeyboardInterrupt as e:
#     113         self.cancel()
#
# File ~/.local/share/virtualenvs/slip-ml-bXUTykFe/lib/python3.11/site-packages/s3transfer/futures.py:267, in TransferCoordinator.result(self)
#     257 """Waits until TransferFuture is done and returns the result
#     258
#     259 If the TransferFuture succeeded, it will return the result. If the
#     260 TransferFuture failed, it will raise the exception associated to the
#     261 failure.
#     262 """
#     263 # Doing a wait() with no timeout cannot be interrupted in python2 but
#     264 # can be interrupted in python3 so we just wait with the largest
#     265 # possible value integer value, which is on the scale of billions of
#     266 # years...
# --> 267 self._done_event.wait(MAXINT)
#     269 # Once done waiting, raise an exception if present or return the
#     270 # final result.
#     271 if self._exception:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
print(f"Total duration: {total_duration/60/60} hours")

# %%
# close the log file
#log_file.close()
